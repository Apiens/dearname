# %%
import requests
from bs4 import BeautifulSoup as bs

# %% [markdown]
# ## fetching bird list

# %%
import pandas as pd
df = pd.read_csv("../bird_list.csv") #2019국가생물종목록 中 "조류" 복붙한것.
df.head()
# Out:
#    No. 분류군                 학명       대표국명         명명자    명명년도 멸종위기종    Phylum  \
# 0    1  조류   Aix galericulata         원앙  (Linnaeus) -1758.0   NaN  Chordata
# 1    2  조류         Anas acuta       고방오리    Linnaeus  1758.0   NaN  Chordata
# 2    3  조류     Anas americana  아메리카홍머리오리      Gmelin  1789.0   NaN  Chordata
# 3    4  조류  Anas carolinensis      미국쇠오리      Gmelin  1789.0   NaN  Chordata
# 4    5  조류      Anas clypeata       넓적부리    Linnaeus  1758.0   NaN  Chordata
#
#        문 Class  ...         Order     목    Family    과 Genus    속 Subgenus  \
# 0  척삭동물문  Aves  ...  Anseriformes  기러기목  Anatidae  오리과   Aix  원앙속      NaN
# 1  척삭동물문  Aves  ...  Anseriformes  기러기목  Anatidae  오리과  Anas  오리속      NaN
# 2  척삭동물문  Aves  ...  Anseriformes  기러기목  Anatidae  오리과  Anas  오리속      NaN
# 3  척삭동물문  Aves  ...  Anseriformes  기러기목  Anatidae  오리과  Anas  오리속      NaN
# 4  척삭동물문  Aves  ...  Anseriformes  기러기목  Anatidae  오리과  Anas  오리속      NaN
#
#    아속       Species          종
# ...

# %%
bird_list= df.values.tolist()
bird_list[0][:5]
# Out:
# [1, '조류', 'Aix galericulata', '원앙', '(Linnaeus)']

# %% [markdown]
# ### Adding English Common Name

# %%
cnt= 0
for bird_info in bird_list:
    response = requests.get(f"https://en.wikipedia.org/wiki/{bird_info[2]}")
    common_name = bs(response.text,'html.parser').title.text[:-12]
    common_names.append(common_name)
    bird_info.append(common_name)
    print(f"{cnt}:{common_name: <40}")# \r", end="")
    cnt += 1
# Out:
# 0:Mandarin duck
# 1:Northern pintail
# 2:American wigeon
# 3:Green-winged teal
# 4:Northern shoveler
# 5:Eurasian teal
# 6:Falcated duck
# 7:Baikal teal
# 8:Eurasian wigeon
# 9:Mallard
# 10:Indian spot-billed duck
# 11:Garganey
# 12:American black duck
# 13:Gadwall
# 14:Greater white-fronted goose
# 15:Greylag goose
# 16:Snow goose
# 17:Emperor goose
# 18:Swan goose
# 19:Lesser white-fronted goose
# 20:Taiga bean goose
# 21:Bar-headed goose
# 22:Redhead (bird)
# 23:Baer's pochard
# 24:Common pochard
# 25:Tufted duck
# 26:Greater scaup
# 27:Ferruginous duck
# 28:Canvasback
# 29:Brant (goose)
# 30:Canada goose
# 31:Red-breasted goose
# 32:Bufflehead
# 33:Common goldeneye
# 34:Barrow's goldeneye
# 35:Long-tailed duck
# 36:Tundra swan
# 37:Whooper swan
# 38:Mute swan
# 39:Harlequin duck
# 40:Black scoter
# 41:White-winged scoter
# 42:Smew
# 43:Common merganser
# 44:Red-breasted merganser
# 45:Scaly-sided merganser
# 46:Red-crested pochard
# 47:King eider
# 48:Crested shelduck
# ...

# %%
for i in bird_list[:10]:
    print(i[-1])
# Out:
# Mandarin duck
# Northern pintail
# American wigeon
# Green-winged teal
# Northern shoveler
# Eurasian teal
# Falcated duck
# Baikal teal
# Eurasian wigeon
# Mallard

# %%
import pickle

with open("../bird_list_new.pkl", "wb") as f:
    pickle.dump(bird_list,f)

# %%
with open("../bird_list_new.pkl", "rb") as f:
    import pickle
    bird_list_new = pickle.load(f)

# %%
len(bird_list_new)
# Out:
# 537

# %%
pd.DataFrame(bird_list_new[:3])
# Out:
#    0   1                 2          3           4       5   6         7   \
# 0   1  조류  Aix galericulata         원앙  (Linnaeus) -1758.0 NaN  Chordata
# 1   2  조류        Anas acuta       고방오리    Linnaeus  1758.0 NaN  Chordata
# 2   3  조류    Anas americana  아메리카홍머리오리      Gmelin  1789.0 NaN  Chordata
#
#       8     9   ...    12        13   14    15   16  17  18            19  \
# 0  척삭동물문  Aves  ...  기러기목  Anatidae  오리과   Aix  원앙속 NaN NaN  galericulata
# 1  척삭동물문  Aves  ...  기러기목  Anatidae  오리과  Anas  오리속 NaN NaN         acuta
# 2  척삭동물문  Aves  ...  기러기목  Anatidae  오리과  Anas  오리속 NaN NaN     americana
#
#           20                21
# 0         원앙     Mandarin duck
# 1       고방오리  Northern pintail
# 2  아메리카홍머리오리   American wigeon
#
# [3 rows x 22 columns]

# %%
bird_dict_list = [{"common_name":i[-1],
                   "common_name_KOR":i[-2],
                   "specific_name":i[-3],
                   "genus":i[-7],
                   "index":"AV_000"+f"{i[0]:0>3}"}
                  for i in bird_list_new]

# %%
#it works when you access in normal shell_plus, not shell_plus --notebook env.
Species.object.create(**bird_dict_list[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-4f7271c75b1e> in <module>
#       1 #it works when you access in normal shell_plus, not shell_plus --notebook env.
# ----> 2 Species.object.create(**bird_dict_list[0])
#
# NameError: name 'Species' is not defined
